# %%
import matplotlib as mpl

# %%
# %matplotlib inline
# %matplotlib notebook

# %%
#Backened setting for matplotlib
#Intereact the matplotlib with the browser
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(3,2)
# Out:
# <img src="data:image/png;base64,..." width="431.818172458775">

# %%
plt.plot(3,2,'.')

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import  Figure

# %%
fig = Figure()
canvas = FigureCanvasAgg(fig)


ax = fig.add_subplot(111)
ax.plot(3,4,'.')
canvas.print_png('test.png')

# %%
# %%html
# <img scr='test.png'>
# Out:
# <img scr='test.png'>

# %%
plt.figure()
plt.plot([3,2],[4,5],'o-')
ax = plt.gca()
ax.axis([0,6,0,10])
# Out:
# <img src="data:image/png;base64,..." width="431.818172458775">
# [0, 6, 0, 10]

# %% [markdown]
# ### Scatter

# %%
import numpy as np

# %%
x = np.arange(1,11)
y=x.copy()

# %%
plt.figure() 
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,..." width="431.818172458775">

# %%
plt.figure()
colors = ['green']* (len(x)-1)
colors.append('red')
plt.scatter(x,y,s=200, c=colors)

# %% [markdown]
# ### Line Plot

# %%
plt.figure()
plt.plot(x,'-o', x**2,'-o')
b = [50,53,55,54]
plt.plot(b, '--r')
# Out:
# <img src="data:image/png;base64,..." width="431.818172458775">

# %%
a = plt.gca()

# %%
a.fill_between(range(len(x)),
              x,
              x**2,
              color = 'blue',
              alpha = 0.25)

# %% [markdown]
# ### Dates

# %%
dates = np.arange('2017-01-01', '2017-01-11',dtype='Datetime64')
dates
# Out:
# array(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#        '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#        '2017-01-09', '2017-01-10'], dtype='datetime64[D]')

# %%
plt.figure()
plt.plot(dates, x)
# Out:
# <img src="data:image/png;base64,..." width="431.818172458775">

# %%
import pandas as pd

# %%
pd_date = list(map(pd.to_datetime , dates))

# %%
plt.figure()
plt.plot(pd_date,x)
# Out:
# <img src="data:image/png;base64,..." width="751.818165522962">
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# rotation of x ticks
x = plt.gca()

# %%
x = x.xaxis

# %%
for item in x.get_ticklabels():
    item.set_rotation(45)

# %%
plt.subplots_adjust(bottom=0.25)
plt.title('$x^2$')
# Out:
# Text(0.5, 1, '$x^2$')

# %%
plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%', 
                 ha='center', color='w', fontsize=11)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-07c37bc3151d> in <module>
# ----> 1 plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%',
#       2                  ha='center', color='w', fontsize=11)
#
# NameError: name 'bar' is not defined
