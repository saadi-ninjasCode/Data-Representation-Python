# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
import numpy as np

# %%
data = np.arange(1,11)

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.subplot(1,2,2)
plt.plot(data,'--')

# %%
fig, ax = plt.subplots(3,3, sharex=True , sharey=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax[1,2].plot(data)

# %%
#label the all figure ticks
for label in plt.gcf().get_axes():
    for l in label.get_xticklabels() + label.get_yticklabels():
        l.set_visible(True)

# %%
plt.gcf().canvas.draw()

# %%
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2, sharex=True)
ax = [ax1,ax2,ax3,ax4]
for a in range(len(ax)):
    sample = 10** (a+1)
    rand_sample = np.random.normal(0.0, 1, size=sample)
    ax[a].hist(rand_sample, bins=1000)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.gridspec import GridSpec

# %%
plt.figure()
gs = GridSpec(3,3)
top = plt.subplot(gs[0,:])
side = plt.subplot(gs[1,:-1])
bottom = plt.subplot(gs[-1,:-1])
last = plt.subplot(gs[1:, 2:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
X = np.random.normal(0.0, 1.0, 10000)
Y = np.random.random(10000)

# %%
top.hist2d(X,Y)
# Out:
# (array([[  2.,   1.,   1.,   1.,   2.,   6.,   2.,   3.,   2.,   1.],
#         [ 11.,  10.,  11.,  17.,  19.,  17.,  14.,  12.,  18.,  13.],
#         [ 68.,  71.,  64.,  62.,  58.,  58.,  61.,  59.,  76.,  68.],
#         [184., 198., 165., 200., 180., 198., 171., 173., 184., 182.],
#         [271., 262., 248., 251., 295., 285., 315., 295., 272., 274.],
#         [256., 248., 246., 275., 258., 269., 271., 258., 266., 253.],
#         [122., 158., 169., 154., 144., 135., 141., 147., 138., 147.],
#         [ 51.,  38.,  48.,  46.,  45.,  48.,  35.,  49.,  45.,  48.],
#         [  5.,   9.,  13.,   8.,   7.,   6.,   7.,   7.,   3.,   6.],
#         [  0.,   1.,   1.,   0.,   1.,   3.,   1.,   0.,   2.,   1.]]),
#  array([-3.65899245, -2.90488772, -2.150783  , -1.39667827, -0.64257355,
#          0.11153118,  0.8656359 ,  1.61974063,  2.37384535,  3.12795008,
#          3.8820548 ]),
#  array([3.26462226e-05, 1.00028069e-01, 2.00023492e-01, 3.00018914e-01,
#         4.00014337e-01, 5.00009760e-01, 6.00005183e-01, 7.00000605e-01,
#         7.99996028e-01, 8.99991451e-01, 9.99986874e-01]),
#  <matplotlib.image.AxesImage at 0x7f46b7386050>)

# %%
side.hist(X)
bottom.hist(Y)
# Out:
# (array([ 970.,  996.,  966., 1014., 1009., 1025., 1018., 1003., 1006.,
#          993.]),
#  array([3.26462226e-05, 1.00028069e-01, 2.00023492e-01, 3.00018914e-01,
#         4.00014337e-01, 5.00009760e-01, 6.00005183e-01, 7.00000605e-01,
#         7.99996028e-01, 8.99991451e-01, 9.99986874e-01]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Animation

# %%
from matplotlib.animation import Animation

# %%
X = np.random.randn(100)
